# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "***Fraud Detection Project***". This is the last project of the Capstone Series.
#
# One of the challenges in this project is the absence of domain knowledge. So without knowing what the column names are, you will only be interested in their values. The other one is the class frequencies of the target variable are quite imbalanced.
#
# You will implement ***Logistic Regression, Random Forest, XGBoost,and Neural Network*** algorithms and ***Unbalanced Data Techniques*** . Also visualize performances of the models using ***Seaborn, Matplotlib*** and ***Yellowbrick*** in a variety of ways.
#
# Data drift and model drirft are key consepts about ML and MLOPS, you can monitor and check your data and models with plenty of ways and tools. ***Deepchecks*** is one of them and the leading tool for testing and for validating your machine learning models and data, and it enables doing so with minimal effort. In this project, you will apply ***Data Integrity, Train-Test Validation, and Model Evaluation*** checks.
# Deepchecks Intruduction : https://youtu.be/7ELdizoi6BU
#
# At the end of the project, you will have the opportunity to deploy your model by ***Streamlit API***.
#
# Before diving into the project, please take a look at the Determines and Tasks.
#
# - ***NOTE:*** *This tutorial assumes that you already know the basics of coding in Python and are familiar with model deployement (Streamlit) as well as the theory behind algorithms*

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
# The datasets contains transactions made by credit cards in September 2013 by european cardholders. This dataset presents transactions that occurred in two days, where it has **492 frauds** out of **284,807** transactions. The dataset is **highly unbalanced**, the positive class (frauds) account for 0.172% of all transactions.
#
# **Feature Information:**
#
# **Time**: This feature is contains the seconds elapsed between each transaction and the first transaction in the dataset.
#
# **Amount**:  This feature is the transaction Amount, can be used for example-dependant cost-senstive learning.
#
# **Class**: This feature is the target variable and it takes value 1 in case of fraud and 0 otherwise.
#
# ---
#
# The aim of this project is to predict whether a credit card transaction is fraudulent. Of course, this is not easy to do.
# First of all, you need to analyze and recognize your data well in order to draw your roadmap and choose the correct arguments you will use. Accordingly, you can examine the frequency distributions of variables. You can observe variable correlations and want to explore multicollinearity. You can display the distribution of the target variable's classes over other variables.
# Also, it is useful to take missing values and outliers.
#
# After these procedures, you can move on to the model building stage by doing the basic data pre-processing you are familiar with.
#
# Start with Logistic Regression and evaluate model performance. You will apply the Unbalanced Data Techniques used to increase the performance. Next, observe their effects.
#
# Then, you will use four different algorithms in the model building phase.
#
# In the final step, you will deploy your model using ***Streamlit API***.
#
# **Optional**: You can Dockerize your project and deploy on cloud.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Tasks
#
# #### 1. Exploratory Data Analysis & Data Cleaning
#
# - Import Modules, Load Data & Data Review
# - Apply data integrity checks
# - Exploratory Data Analysis
# - Data Cleaning
#
# #### 2. Data Preprocessing
#
# - Train - Test Split
# - Train - Test Split Validation Checks
# - Scaling
#
# #### 3. Model Building
#
# - Logistic Regression
# - Random Forest Classifier
# - XGBoost Classifier
# - Neural Network
# -
#
# #### 4. Model Deployement
#
# - Save and Export the Best Model
# - Save and Export Variables

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 1. Exploratory Data Analysis & Data Cleaning

# %% [markdown]
# ### Import Modules, Load Data & Data Review

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime
from datetime import timedelta
import plotly.express as px
import plotly.graph_objects as go
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
import matplotlib.gridspec as gridspec
from sklearn.preprocessing import PowerTransformer, StandardScaler, scale, OneHotEncoder, OrdinalEncoder, MinMaxScaler, RobustScaler
from sklearn.compose import make_column_transformer
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.metrics import silhouette_samples, silhouette_score, calinski_harabasz_score, davies_bouldin_score, adjusted_rand_score, mean_squared_error, mean_absolute_error, r2_score, accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report, make_scorer, precision_recall_curve, PrecisionRecallDisplay, average_precision_score
from sklearn.model_selection import GridSearchCV, cross_validate, train_test_split, StratifiedKFold
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.utils import class_weight
from scikitplot.metrics import plot_precision_recall, plot_roc, precision_recall_curve
from scipy.cluster.hierarchy import linkage, dendrogram
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer, InterclusterDistance
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.neighbors import KNeighborsClassifier
from kneed import KneeLocator
import math
import pickle
from scipy.stats import chi2_contingency, skew, stats
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import load_model
from ipywidgets import interact
from scipy.stats import levene
from livelossplot import PlotLossesKerasTF
from feature_engine.selection import DropDuplicateFeatures, DropConstantFeatures, DropCorrelatedFeatures, RecursiveFeatureAddition
from imblearn.over_sampling import BorderlineSMOTE,ADASYN,KMeansSMOTE,SMOTE,RandomOverSampler,SVMSMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn.linear_model import LogisticRegression
from deepchecks.tabular import Dataset
from deepchecks.tabular.suites import train_test_validation, model_evaluation, data_integrity
from deepchecks.tabular.checks import IsSingleValue, DataDuplicates
import sys
from collections import Counter
from tensorflow.keras.metrics import RecallAtPrecision

import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df = pd.read_csv("creditcard.csv")
df_copy = df.copy()
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.918649e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.682686e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.761736e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.811118e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552103e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.040130e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.698953e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.893285e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.147640e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.772925e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.289524e-16      1.020713   -4.797473     -0.762494
# ...

# %%
df.groupby("Class").mean().T
# Out:
# Class              0             1
# Time    94838.202258  80746.806911
# V1          0.008258     -4.771948
# V2         -0.006271      3.623778
# V3          0.012171     -7.033281
# V4         -0.007860      4.542029
# V5          0.005453     -3.151225
# V6          0.002419     -1.397737
# V7          0.009637     -5.568731
# V8         -0.000987      0.570636
# V9          0.004467     -2.581123
# V10         0.009824     -5.676883
# V11        -0.006576      3.800173
# V12         0.010832     -6.259393
# V13         0.000189     -0.109334
# V14         0.012064     -6.971723
# V15         0.000161     -0.092929
# V16         0.007164     -4.139946
# V17         0.011535     -6.665836
# V18         0.003887     -2.246308
# V19        -0.001178      0.680659
# V20        -0.000644      0.372319
# V21        -0.001235      0.713588
# V22        -0.000024      0.014049
# V23         0.000070     -0.040308
# V24         0.000182     -0.105130
# V25        -0.000072      0.041449
# ...

# %%
df["Class"].value_counts(normalize=True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %%
df["Amount"].describe().T
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
(df["Amount"]<0).sum()
# Out:
# 0

# %% [markdown]
# ## Apply Data Integrity Checks
# * link: https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_data_integrity.html

# %%
ds = Dataset(df, label="Class",datetime_name = "Time")

integ_suite = data_integrity()
suite_result = integ_suite.run(ds)
suite_result.show()
# Out:
# deepchecks - WARNING - It is recommended to initialize Dataset with categorical features by doing "Dataset(df, cat_features=categorical_list)". No categorical features were passed, therefore heuristically inferring categorical features in the data. 0 categorical features were inferred.
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
# ...

# %%
IsSingleValue().run(df)
# Out:
# deepchecks - WARNING - Received a "pandas.DataFrame" instance. It is recommended to pass a "deepchecks.tabular.Dataset" instance by initializing it with the data and metadata, for example by doing "Dataset(dataframe, label=label, cat_features=cat_features)"
# deepchecks - WARNING - It is recommended to initialize Dataset with categorical features by doing "Dataset(df, cat_features=categorical_list)". No categorical features were passed, therefore heuristically inferring categorical features in the data. 1 categorical features were inferred.: Class
# ...

# %%
single_value_with_condition = IsSingleValue().add_condition_not_single_value()
result = single_value_with_condition.run(ds)
result.show()

# %%
df.drop_duplicates(inplace=True)
ds = Dataset(df,  datetime_name='Time', label='Class')
result = DataDuplicates().add_condition_ratio_less_or_equal(0).run(ds)
result.show()
# Out:
# deepchecks - WARNING - It is recommended to initialize Dataset with categorical features by doing "Dataset(df, cat_features=categorical_list)". No categorical features were passed, therefore heuristically inferring categorical features in the data. 0 categorical features were inferred.
# ...

# %%
integ_suite
# Out:
# Data Integrity Suite: [
# 	0: IsSingleValue
# 		Conditions:
# 			0: Does not contain only a single value
# 	1: SpecialCharacters
# 		Conditions:
# 			0: Ratio of samples containing solely special character is less or equal to 0.1%
# 	2: MixedNulls
# 		Conditions:
# 			0: Number of different null types is less or equal to 1
# 	3: MixedDataTypes
# 		Conditions:
# 			0: Rare data types in column are either more than 10% or less than 1% of the data
# 	4: StringMismatch
# 		Conditions:
# 			0: No string variants
# 	5: DataDuplicates
# 		Conditions:
# 			0: Duplicate data ratio is less or equal to 0%
# 	6: StringLengthOutOfBounds
# 		Conditions:
# 			0: Ratio of string length outliers is less or equal to 0%
# 	7: ConflictingLabels
# 		Conditions:
# 			0: Ambiguous sample ratio is less or equal to 0%
# 	8: OutlierSampleDetection
# 	9: FeatureLabelCorrelation(ppscore_params={}, random_state=42)
# 		Conditions:
# 			0: Features' Predictive Power Score is less than 0.8
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
print("Class as pie chart:")
fig, ax = plt.subplots(1, 1,figsize=(15,8))
ax.pie(df.Class.value_counts(),autopct='%1.3f%%', labels=['Non_Fraud','Fraud'], colors=['maroon','Black'],textprops={'color':"blue"})
plt.axis('equal')
plt.xlabel('fraud or non-froud,that is the whole case');
# Out:
# Class as pie chart:

# %%
sns.boxplot(data=df, x='Amount')
plt.show()

# %%
fig = plt.figure(figsize=(12, 8))

sns.scatterplot(data=df, x='Time', y='Amount',hue="Class")
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(12,4))

bins = 50

ax1.hist(df.Time[df.Class == 1], bins = bins)
ax1.set_title('Fraud')

ax2.hist(df.Time[df.Class == 0], bins = bins)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Number of Transactions')
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.set_style("whitegrid", {'axes.grid' : False})
sns.kdeplot(df['Amount'],shade=True, color ="g")
ax2 = plt.axes([1, 0.35, .4, .15], facecolor='w')
sns.kdeplot(data =df[df["Class"] == 1],  x = "Amount", shade= True );
ax2.set_title('Fraud')
ax2.set_xlim([0,2000]);
ax3 = plt.axes([1, 0.6, .4, .15], facecolor='w')
sns.kdeplot(data =df[df["Class"] == 0],  x = "Amount",color= "y", shade= True );
ax3.set_title('Normal')
ax3.set_xlim([0,2000]);

# %%
plt.figure(figsize = (16,6))
ax = sns.distplot(df[df["Class"] == 0].Time, color='r')
ax.set_title('Distribution of Time Normal Class')
ax.set_xlim([min(df.Time), max(df.Time)])
# Out:
# (0.0, 172792.0)

# %%
plt.figure(figsize = (16,6))
ax = sns.distplot(df[df["Class"] == 1].Time, color='r')
ax.set_title('Distribution of Time of Fraud Class')
ax.set_xlim([min(df.Time), max(df.Time)])
# Out:
# (0.0, 172792.0)

# %%
sns.set_style("whitegrid", {'axes.grid' : False})
df.drop(columns = ['Class']).corrwith(df.Class).plot.barh(
        figsize = (20, 15), fontsize = 15, grid = True, color = "maroon")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (14,14))
plt.title('Credit Card Transactions features correlation plot (Pearson)')
corr = df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,cmap="Reds")
plt.show()

# %%
plt.figure(figsize=(35,20))
sns.heatmap(df.corr(),annot=True,cmap="tab20c")
plt.show()

# %%
v_features = df.iloc[:,1:29].columns
plt.figure(figsize=(12,28*4))
gs = gridspec.GridSpec(28, 1)
for i, cn in enumerate(df[v_features]):
    ax = plt.subplot(gs[i])
    sns.distplot(df[cn][df.Class == 1], bins=50)
    sns.distplot(df[cn][df.Class == 0], bins=50)
    ax.set_xlabel('')
    ax.set_title('histogram of feature: ' + str(cn))
plt.show()

# %%
numeric_columns = (list(df.loc[:, 'Time':'Amount']))

fig = plt.figure(figsize=(20, 50))
rows, cols = 10, 3
for idx, num in enumerate(numeric_columns[:30]):
    ax = fig.add_subplot(rows, cols, idx+1)
    ax.grid(alpha = 0.7, axis ="both")
    sns.kdeplot(x = num, fill = True,color ="#3386FF",linewidth=0.6, data = df, label = "Train")
   
    ax.set_xlabel(num)
    ax.legend()
fig.tight_layout()
fig.show()

# %%
f, axes = plt.subplots(ncols=4, figsize=(20,8))

# Negative Correlations with our Class (The lower our feature value the more likely it will be a fraud transaction)
sns.boxplot(x="Class", y="V17", data=df, palette="pastel", ax=axes[0])
axes[0].set_title('V17 vs Class Negative Correlation')

sns.boxplot(x="Class", y="V14", data=df, palette="pastel", ax=axes[1])
axes[1].set_title('V14 vs Class Negative Correlation')


sns.boxplot(x="Class", y="V12", data=df, palette="pastel", ax=axes[2])
axes[2].set_title('V12 vs Class Negative Correlation')


sns.boxplot(x="Class", y="V10", data=df, palette="pastel", ax=axes[3])
axes[3].set_title('V10 vs Class Negative Correlation')

plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=3,figsize=(11,17))
fig.suptitle('Features vs Class\n', size = 18)

sns.boxplot(ax=axes[0, 0], data=df, x='Class', y='V17', palette='Spectral')
axes[0,0].set_title("V17 distribution");

sns.boxplot(ax=axes[0, 1], data=df, x='Class', y='V10', palette='Spectral')
axes[0,1].set_title("V10 distribution");

sns.boxplot(ax=axes[0, 2], data=df, x='Class', y='V12', palette='Spectral')
axes[0,2].set_title("V12 distribution");

sns.boxplot(ax=axes[1, 0], data=df, x='Class', y='V16', palette='Spectral')
axes[1,0].set_title("V16 distribution");

sns.boxplot(ax=axes[1, 1], data=df, x='Class', y='V14', palette='Spectral')
axes[1,1].set_title("V14 distribution");

sns.boxplot(ax=axes[1, 2], data=df, x='Class', y='V3', palette='Spectral')
axes[1,2].set_title("V3 distribution");

sns.boxplot(ax=axes[2, 0], data=df, x='Class', y='V7', palette='Spectral')
axes[2,0].set_title("V7 distribution");

sns.boxplot(ax=axes[2, 1], data=df, x='Class', y='V11', palette='Spectral')
axes[2,1].set_title("V11 distribution");

sns.boxplot(ax=axes[2, 2], data=df, x='Class', y='V4', palette='Spectral')
axes[2,2].set_title("V4 distribution");

plt.tight_layout()

# %%
plt.style.use('ggplot') # Using ggplot2 style visuals 

f, ax = plt.subplots(figsize=(11, 15))

ax.set_facecolor('#fafafa')
ax.set(xlim=(-5, 5))
plt.ylabel('Variables')
plt.title("Overview Data Set")
ax = sns.boxplot(data = df.drop(columns=['Amount', 'Class', 'Time']), 
  orient = 'h', 
  palette = 'Set2')

# %%
def plot_distribution(data_select) : 
    figsize =( 15, 8)
    sns.set_style("ticks")
    s = sns.FacetGrid(df, hue = 'Class',aspect = 2.5, palette ={0 : 'lime', 1 :'black'})
    s.map(sns.kdeplot, data_select, shade = True, alpha = 0.6)
    s.set(xlim=(df[data_select].min(), df[data_select].max()))
    s.add_legend()
    s.set_axis_labels(data_select, 'proportion')
    s.fig.suptitle(data_select)
    plt.show()

# %%
plot_distribution('V2')

# %%
plot_distribution('V4')

# %%
plot_distribution('V11')

# %%
df['Hour'] = df['Time'].apply(lambda x: np.floor(x / 3600))

tmp = df.groupby(['Hour', 'Class'])['Amount'].aggregate(['min', 'max', 'count', 'sum', 'mean', 'median', 'var']).reset_index()
df1 = pd.DataFrame(tmp)
df1.columns = ['Hour', 'Class', 'Min', 'Max', 'Transactions', 'Sum', 'Mean', 'Median', 'Var']
df1.head()
# Out:
#    Hour  Class   Min      Max  Transactions        Sum        Mean   Median  \
# 0   0.0      0   0.0  7712.43          3929  255825.95   65.112230   12.990
# 1   0.0      1   0.0   529.00             2     529.00  264.500000  264.500
# 2   1.0      0   0.0  1769.69          2211  145744.59   65.917951   23.000
# 3   1.0      1  59.0   239.93             2     298.93  149.465000  149.465
# 4   2.0      0   0.0  4002.88          1552  106983.39   68.932597   17.985
#
#              Var
# 0   45961.838558
# 1  139920.500000
# 2   20085.295527
# 3   16367.832450
# 4   45434.509936

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="Hour", y="Sum", data=df1.loc[df1.Class==0])
s = sns.lineplot(ax = ax2, x="Hour", y="Sum", data=df1.loc[df1.Class==1], color="red")
plt.suptitle("Total Amount")
plt.show();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="Hour", y="Transactions", data=df1.loc[df1.Class==0])
s = sns.lineplot(ax = ax2, x="Hour", y="Transactions", data=df1.loc[df1.Class==1], color="red")
plt.suptitle("Total Number of Transactions")
plt.show();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="Hour", y="Mean", data=df1.loc[df1.Class==0])
s = sns.lineplot(ax = ax2, x="Hour", y="Mean", data=df1.loc[df1.Class==1], color="red")
plt.suptitle("Average Amount of Transactions")
plt.show();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
s = sns.boxplot(ax = ax1, x="Class", y="Amount", hue="Class",data=df, palette="PRGn",showfliers=True)
s = sns.boxplot(ax = ax2, x="Class", y="Amount", hue="Class",data=df, palette="PRGn",showfliers=False)
plt.show()

# %% [markdown]
# ### Data Cleaning
# Check Missing Values and Outliers

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
num_cols = [col for col in df.columns if df[col].dtypes != "O"]

# %%
def IQR_method (df,n,num_cols):
    """
    Takes a dataframe and returns an index list corresponding to the observations 
    containing more than n outliers according to the Tukey IQR method.
    """
    outlier_list = []
    
    for column in num_cols:
                
        # 1st quartile (25%)
        Q1 = np.percentile(df[column], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(df[column],75)
        
        # Interquartile range (IQR)
        IQR = Q3 - Q1
        
        # outlier step
        outlier_step = 3.5 * IQR
        
        # Determining a list of indices of outliers
        outlier_list_column = df[(df[column] < Q1 - outlier_step) | (df[column] > Q3 + outlier_step )].index
        
        # appending the list of outliers 
        outlier_list.extend(outlier_list_column)
        
    # selecting observations containing more than x outliers
    outlier_list = Counter(outlier_list)        
    multiple_outliers = list( k for k, v in outlier_list.items() if v > n )
    
    # Calculate the number of records below and above lower and above bound value respectively
    df1 = df[df[column] < Q1 - outlier_step]
    df2 = df[df[column] > Q3 + outlier_step]
    
    print('Total number of outliers is:', df1.shape[0]+df2.shape[0])
    
    return multiple_outliers

# %%
Outliers_IQR = IQR_method(df,1,num_cols)
# Out:
# Total number of outliers is: 473

# %%
df_out = df.drop(Outliers_IQR, axis = 0).reset_index(drop=True)

# %%
df.shape, df_out.shape
# Out:
# ((283726, 31), (202701, 31))

# %%
fig, axes = plt.subplots(nrows=10, ncols=3,figsize=(13,30))
fig.suptitle('Distributions of features after dropping outliers using Standard Deviation Method\n', size = 18)


axes[0,0].hist(df_out['V1'], bins=60, linewidth=0.5, edgecolor="white")
axes[0,0].set_title("V1 distribution");

axes[0,1].hist(df_out['V2'], bins=60, linewidth=0.5, edgecolor="white")
axes[0,1].set_title("V2 distribution");

axes[0,2].hist(df_out['V3'], bins=60, linewidth=0.5, edgecolor="white")
axes[0,2].set_title("V3 distribution");

axes[1,0].hist(df_out['V4'], bins=60, linewidth=0.5, edgecolor="white")
axes[1,0].set_title("V4 distribution");

axes[1,1].hist(df_out['V5'], bins=60, linewidth=0.5, edgecolor="white")
axes[1,1].set_title("V5 distribution");

axes[1,2].hist(df_out['V6'], bins=60, linewidth=0.5, edgecolor="white")
axes[1,2].set_title("V6 distribution");

axes[2,0].hist(df_out['V7'], bins=60, linewidth=0.5, edgecolor="white")
axes[2,0].set_title("V7 distribution");

axes[2,1].hist(df_out['V8'], bins=60, linewidth=0.5, edgecolor="white")
axes[2,1].set_title("V8 distribution");

axes[2,2].hist(df_out['V9'], bins=60, linewidth=0.5, edgecolor="white")
axes[2,2].set_title("V9 distribution");

axes[3,0].hist(df_out['V10'], bins=60, linewidth=0.5, edgecolor="white")
axes[3,0].set_title("V10 distribution");

axes[3,1].hist(df_out['V11'], bins=60, linewidth=0.5, edgecolor="white")
axes[3,1].set_title("V11 distribution");

axes[3,2].hist(df_out['V12'], bins=60, linewidth=0.5, edgecolor="white")
axes[3,2].set_title("V12 distribution");

axes[4,0].hist(df_out['V13'], bins=60, linewidth=0.5, edgecolor="white")
axes[4,0].set_title("V13 distribution");

axes[4,1].hist(df_out['V14'], bins=60, linewidth=0.5, edgecolor="white")
axes[4,1].set_title("V14 distribution");

axes[4,2].hist(df_out['V15'], bins=60, linewidth=0.5, edgecolor="white")
axes[4,2].set_title("V15 distribution");

axes[5,0].hist(df_out['V16'], bins=60, linewidth=0.5, edgecolor="white")
axes[5,0].set_title("V16 distribution");

axes[5,1].hist(df_out['V17'], bins=60, linewidth=0.5, edgecolor="white")
axes[5,1].set_title("V17 distribution");

axes[5,2].hist(df_out['V18'], bins=60, linewidth=0.5, edgecolor="white")
axes[5,2].set_title("V18 distribution");

axes[6,0].hist(df_out['V19'], bins=60, linewidth=0.5, edgecolor="white")
axes[6,0].set_title("V19 distribution");

axes[6,1].hist(df_out['V20'], bins=60, linewidth=0.5, edgecolor="white")
axes[6,1].set_title("V20 distribution");

axes[6,2].hist(df_out['V21'], bins=60, linewidth=0.5, edgecolor="white")
axes[6,2].set_title("V21 distribution");

axes[7,0].hist(df_out['V22'], bins=60, linewidth=0.5, edgecolor="white")
axes[7,0].set_title("V22 distribution");

axes[7,1].hist(df_out['V23'], bins=60, linewidth=0.5, edgecolor="white")
axes[7,1].set_title("V23 distribution");

axes[7,2].hist(df_out['V24'], bins=60, linewidth=0.5, edgecolor="white")
axes[7,2].set_title("V24 distribution");

axes[8,0].hist(df_out['V25'], bins=60, linewidth=0.5, edgecolor="white")
axes[8,0].set_title("V25 distribution");

axes[8,1].hist(df_out['V26'], bins=60, linewidth=0.5, edgecolor="white")
axes[8,1].set_title("V26 distribution");

axes[8,2].hist(df_out['V27'], bins=60, linewidth=0.5, edgecolor="white")
axes[8,2].set_title("V27 distribution");

axes[9,0].hist(df_out['V28'], bins=60, linewidth=0.5, edgecolor="white")
axes[9,0].set_title("V28 distribution");

axes[9,1].hist(df_out['Time'], bins=60, linewidth=0.5, edgecolor="white")
axes[9,1].set_title("Time distribution");

axes[9,2].hist(df_out['Amount'], bins=60, linewidth=0.5, edgecolor="white")
axes[9,2].set_title("Amount distribution");


plt.tight_layout()

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# #### Train - Test Split
#
# As in this case, for extremely imbalanced datasets you may want to make sure that classes are balanced across train and test data.

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(labels=['Class'], axis=1), 
                                                    df['Class'], stratify = df['Class'], test_size=0.3, random_state=0)

X_train.shape, X_test.shape
# Out:
# ((198608, 30), (85118, 30))

# %% [markdown]
# ## Train-Test Validation Checks
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_train_test_validation.html

# %%
train = X_train.copy()
test = X_test.copy()
train["label"] = y_train
test["label"] = y_test

train_ds = Dataset(train, label="label")
test_ds = Dataset(test, label="label")

validation_suite = train_test_validation()
suite_result = validation_suite.run(train_ds, test_ds)
suite_result
# Out:
# deepchecks - WARNING - It is recommended to initialize Dataset with categorical features by doing "Dataset(df, cat_features=categorical_list)". No categorical features were passed, therefore heuristically inferring categorical features in the data. 0 categorical features were inferred.
# deepchecks - WARNING - It is recommended to initialize Dataset with categorical features by doing "Dataset(df, cat_features=categorical_list)". No categorical features were passed, therefore heuristically inferring categorical features in the data. 0 categorical features were inferred.
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
# ...

# %%
suite_result.save_as_html(as_widget=False)
# Out:
# 'output.html'

# %% [markdown]
# #### Scaling

# %%
scaler = RobustScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

oversample = RandomOverSampler(sampling_strategy=0.1, random_state=1)
X_train_over, y_train_over = oversample.fit_resample(X_train, y_train)
X_train_over = pd.DataFrame(X_train_over, columns=X_train.columns)
test = pd.DataFrame(y_train_over, columns = ['Class'])
fig, axs = plt.subplots(ncols=2, figsize=(13,4.5))
sns.countplot(x="Class", data=df, ax=axs[0])
sns.countplot(x="Class", data=test, ax=axs[1])

fig.suptitle("Class repartition before and after undersampling")
a1=fig.axes[0]
a1.set_title("Before")
a2=fig.axes[1]
a2.set_title("After")
# Out:
# Text(0.5, 1.0, 'After')

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 3. Model Building
# It was previously stated that you need to make class prediction with three different algorithms. As in this case, different approaches are required to obtain better performance on unbalanced data.
#
# This dataset is severely **unbalanced** (most of the transactions are non-fraud). So the algorithms are much more likely to classify new observations to the majority class and high accuracy won't tell us anything. To address the problem of imbalanced dataset, we can use undersampling and oversampling or class weight and optimum thresold techniques.
#
# ***Note***:
#
# - *Do not forget to import the necessary libraries and modules before starting the model building!*
#
# - *If you are going to use the cross validation method to be more sure of the performance of your model for unbalanced data, you should make sure that the class distributions in the iterations are equal. For this case, you should use **[StratifiedKFold](https://www.analyseup.com/python-machine-learning/stratified-kfold.html)** instead of regular cross validation method.*

# %% [markdown]
# ### Logistic Regression
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Import Libraries*
#
#    *ii. Model Training*
#
#    *iii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning*
#
#    *iv. Plot Precision and Recall Curve*

# %% [markdown]
# ***i. Feature Selection***

# %%
model = LogisticRegression()

rfa_log = RecursiveFeatureAddition(
    variables=None,  # automatically evaluate all numerical variables
    estimator=model,  # the ML model
    scoring=make_scorer(f1_score, average=None, labels=[1]),  # the metric we want to evalute
    threshold=0.0001,  # the minimum performance increase needed to select a feature
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=1)  # cross-validation
)

rfa_log.fit(X_train_over, y_train_over)
print(rfa_log.initial_model_performance_)
rfa_log.feature_importances_.plot.bar(figsize=(20,6))
plt.xlabel('Features')
plt.ylabel('Importance')
plt.show();
# Out:
# 0.912377847007247

# %%
X_train_final = rfa_log.transform(X_train_over)
X_test_final = rfa_log.transform(X_test)
print(X_train_over.shape, X_train_final.shape, X_test.shape, X_test_final.shape)
# Out:
# (218104, 30) (218104, 9) (85118, 30) (85118, 9)

# %% [markdown]
# ***ii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning***

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
scoring=make_scorer(f1_score, average=None, labels=[1])
param_grid = {'penalty':["l1", "l2", 'none', 'elasticnet'],
             'C':[0.01, 0.1, 1, 5, 16, 19, 22, 25],
             'solver':['liblinear', 'lbfgs']}
log_grid_model = GridSearchCV(LogisticRegression(), param_grid = param_grid, scoring = scoring, 
                          cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1).split(X_train_final, y_train_over), n_jobs = -1, return_train_score=True)
log_grid_model.fit(X_train_final, y_train_over)
# Out:
# GridSearchCV(cv=<generator object _BaseKFold.split at 0x000001EEBCE15AF0>,
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 5, 16, 19, 22, 25],
#                          'penalty': ['l1', 'l2', 'none', 'elasticnet'],
#                          'solver': ['liblinear', 'lbfgs']},
#              return_train_score=True,
#              scoring=make_scorer(f1_score, average=None, labels=[1]))

# %%
log_grid_model.best_params_
# Out:
# {'C': 0.01, 'penalty': 'none', 'solver': 'lbfgs'}

# %%
eval_metric(log_grid_model, X_train_final, y_train_over, X_test_final, y_test)
# Out:
# Test_Set
# [[84808   168]
#  [   20   122]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84976
#            1       0.42      0.86      0.56       142
#
#     accuracy                           1.00     85118
#    macro avg       0.71      0.93      0.78     85118
# weighted avg       1.00      1.00      1.00     85118
#
#
# Train_Set
# [[197911    366]
#  [  2758  17069]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    198277
#            1       0.98      0.86      0.92     19827
#
#     accuracy                           0.99    218104
#    macro avg       0.98      0.93      0.95    218104
# weighted avg       0.99      0.99      0.99    218104

# %% [markdown]
# You're evaluating "accuracy score"? Is your performance metric reflect real success? You may need to use different metrics to evaluate performance on unbalanced data. You should use **[precision and recall metrics](https://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html#:~:text=The%20precision%2Drecall%20curve%20shows,a%20low%20false%20negative%20rate.)**.

# %% [markdown]
# ***iii. Plot Precision and Recall Curve***

# %%
display = PrecisionRecallDisplay.from_estimator(
    log_grid_model, X_test_final, y_test, name="lr")

# %% [markdown]
# ***iv. Apply Model Evaluation Checks***
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_model_evaluation.html

# %%
train_ds = Dataset(X_train_final.reset_index(drop=True), label=y_train_over.reset_index(drop=True), cat_features=[])
test_ds = Dataset(X_test_final.reset_index(drop=True), label=y_test.reset_index(drop=True), cat_features=[])

# %%
evaluation_suite = model_evaluation()
suite_result = evaluation_suite.run(train_ds, test_ds, log_grid_model)
# Note: the result can be saved as html using suite_result.save_as_html()
# or exported to json using suite_result.to_json()
suite_result.show()
# Out:
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
# deepchecks - WARNING - Could not find built-in feature importance on the model, using permutation feature importance calculation instead
# deepchecks - INFO - Calculating permutation feature importance. Expected to finish in 3 seconds
# ...

# %%
suite_result.save_as_html(as_widget=False)
# Out:
# 'output (1).html'

# %%
X_test_final = rfa_log.transform(X_test)
y_pred = log_grid_model.predict(X_test_final)
y_pred_proba = log_grid_model.predict_proba(X_test_final)
log_pre_score = average_precision_score(y_test, y_pred_proba[:,1])
log_f1 = f1_score(y_test, y_pred)
log_recall = recall_score(y_test, y_pred)
print(log_pre_score, log_f1, log_recall)
# Out:
# 0.7534570305495434 0.5648148148148149 0.8591549295774648

# %% [markdown]
# ### Random Forest Classifier with Unbalanced Data Techniques
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Model Training*
#
#    *ii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning*
#
#    *iii. Plot Precision and Recall Curve*

# %% [markdown]
# ***i. Feature Selection***

# %%
model = RandomForestClassifier(n_jobs = -1)

rfa_rf = RecursiveFeatureAddition(
    variables=None,  # automatically evaluate all numerical variables
    estimator=model,  # the ML model
    scoring=make_scorer(f1_score, average=None, labels=[1]),  # the metric we want to evalute
    threshold=0.0001,  # the minimum performance increase needed to select a feature
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=1)  # cross-validation
)

rfa_rf.fit(X_train_over, y_train_over)
print(rfa_rf.initial_model_performance_)
rfa_rf.feature_importances_.plot.bar(figsize=(20,6))
plt.xlabel('Features')
plt.ylabel('Importance')
plt.show();
# Out:
# 0.999521166134819

# %%
X_train_final = rfa_rf.transform(X_train_over)
X_test_final = rfa_rf.transform(X_test)
print(X_train_over.shape, X_train_final.shape, X_test.shape, X_test_final.shape)
# Out:
# (218104, 30) (218104, 6) (85118, 30) (85118, 6)

# %% [markdown]
# ***ii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning***

# %%
scoring=make_scorer(f1_score, average=None, labels=[1])
param_grid = {'n_estimators':[50, 100],
             'max_features':[2, 4, 10],
             'max_depth':[2, 3],
             #'min_samples_split':[2, 3, 4],
             #'min_samples_leaf': [2, 3, 4],
             'max_samples':[0.8]}
rf_grid_model = GridSearchCV(RandomForestClassifier(n_jobs = -1), param_grid = param_grid, scoring = scoring, 
                          cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1).split(X_train_final, y_train_over), n_jobs = -1, return_train_score=True)
rf_grid_model.fit(X_train_final, y_train_over)
# Out:
# GridSearchCV(cv=<generator object _BaseKFold.split at 0x000001EEE5AE8DD0>,
#              estimator=RandomForestClassifier(n_jobs=-1), n_jobs=-1,
#              param_grid={'max_depth': [2, 3], 'max_features': [2, 4, 10],
#                          'max_samples': [0.8], 'n_estimators': [50, 100]},
#              return_train_score=True,
#              scoring=make_scorer(f1_score, average=None, labels=[1]))

# %%
rf_grid_model.best_params_
# Out:
# {'max_depth': 3, 'max_features': 4, 'max_samples': 0.8, 'n_estimators': 100}

# %%
eval_metric(rf_grid_model, X_train_final, y_train_over, X_test_final, y_test)
# Out:
# Test_Set
# [[84912    64]
#  [   22   120]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84976
#            1       0.65      0.85      0.74       142
#
#     accuracy                           1.00     85118
#    macro avg       0.83      0.92      0.87     85118
# weighted avg       1.00      1.00      1.00     85118
#
#
# Train_Set
# [[198118    159]
#  [  3006  16821]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    198277
#            1       0.99      0.85      0.91     19827
#
#     accuracy                           0.99    218104
#    macro avg       0.99      0.92      0.95    218104
# weighted avg       0.99      0.99      0.98    218104

# %% [markdown]
# ***iii. Plot Precision and Recall Curve***

# %%
display = PrecisionRecallDisplay.from_estimator(
    rf_grid_model, X_test_final, y_test, name="rf")

# %% [markdown]
# ***v. Apply Model Evaluation Checks***
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_model_evaluation.html

# %%
train_ds = Dataset(X_train_final.reset_index(drop=True), label=y_train_over.reset_index(drop=True), cat_features=[])
test_ds = Dataset(X_test_final.reset_index(drop=True), label=y_test.reset_index(drop=True), cat_features=[])

evaluation_suite = model_evaluation()
suite_result = evaluation_suite.run(train_ds, test_ds, rf_grid_model)
# Note: the result can be saved as html using suite_result.save_as_html()
# or exported to json using suite_result.to_json()
suite_result.show()
# Out:
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
# deepchecks - WARNING - Could not find built-in feature importance on the model, using permutation feature importance calculation instead
# deepchecks - INFO - Calculating permutation feature importance. Expected to finish in 10 seconds
# ...

# %%
X_test_final = rfa_rf.transform(X_test)
y_pred = rf_grid_model.predict(X_test_final)
y_pred_proba = rf_grid_model.predict_proba(X_test_final)
rf_pre_score = average_precision_score(y_test, y_pred_proba[:,1])
rf_f1 = f1_score(y_test, y_pred)
rf_recall = recall_score(y_test, y_pred)
print(rf_pre_score, rf_f1, rf_recall)
# Out:
# 0.7729812464605237 0.7361963190184049 0.8450704225352113

# %% [markdown]
# ### XGBoost Classifier with Unbalanced Data Techniques
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Model Training*
#
#    *ii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning*
#
#    *iii. Plot Precision and Recall Curve*

# %% [markdown]
# ***i. Feature Selection***

# %%
model = XGBClassifier(n_jobs = -1, random_state=101, metric = 'logloss')

rfa_xgb = RecursiveFeatureAddition(
    variables=None,  # automatically evaluate all numerical variables
    estimator=model,  # the ML model
    scoring=make_scorer(f1_score, average=None, labels=[1]),  # the metric we want to evalute
    threshold=0.0001,  # the minimum performance increase needed to select a feature
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=1)  # cross-validation
)

rfa_xgb.fit(X_train_over, y_train_over)
print(rfa_xgb.initial_model_performance_)
rfa_xgb.feature_importances_.plot.bar(figsize=(20,6))
plt.xlabel('Features')
plt.ylabel('Importance')
plt.show();
# Out:
# [15:59:52] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:59:52] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:00:00] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "metric" } might not be used.
#
# ...

# %%
X_train_final = rfa_xgb.transform(X_train_over)
X_test_final = rfa_xgb.transform(X_test)
print(X_train_over.shape, X_train_final.shape, X_test.shape, X_test_final.shape)
# Out:
# (218104, 30) (218104, 7) (85118, 30) (85118, 7)

# %% [markdown]
# ***ii. Prediction and Model Evaluating (Apply StratifiedKFold) and Tuning***

# %%
scoring=make_scorer(f1_score, average=None, labels=[1])
param_grid = {"n_estimators":[50],'max_depth':[3], "learning_rate": [0.1],
             "subsample":[0.2], "colsample_bytree":[0.2], "colsample_bylevel":[1]}
xgb_grid_model = GridSearchCV(XGBClassifier(n_jobs = -1, random_state=101), param_grid = param_grid, scoring = scoring, 
                          cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1).split(X_train_final, y_train_over), n_jobs = -1, return_train_score=True)
xgb_grid_model.fit(X_train_final, y_train_over)
# Out:
# [16:15:32] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(cv=<generator object _BaseKFold.split at 0x000001EE890B9A10>,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      enable_categorical=False, gamma=None,
#                                      gpu_id=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
# ...

# %%
xgb_grid_model.best_params_
# Out:
# {'colsample_bylevel': 1,
#  'colsample_bytree': 0.2,
#  'learning_rate': 0.1,
#  'max_depth': 3,
#  'n_estimators': 50,
#  'subsample': 0.2}

# %%
eval_metric(xgb_grid_model, X_train_final, y_train_over, X_test_final, y_test)
# Out:
# Test_Set
# [[84929    47]
#  [   23   119]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84976
#            1       0.72      0.84      0.77       142
#
#     accuracy                           1.00     85118
#    macro avg       0.86      0.92      0.89     85118
# weighted avg       1.00      1.00      1.00     85118
#
#
# Train_Set
# [[198147    130]
#  [  3162  16665]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    198277
#            1       0.99      0.84      0.91     19827
#
#     accuracy                           0.98    218104
#    macro avg       0.99      0.92      0.95    218104
# weighted avg       0.99      0.98      0.98    218104

# %% [markdown]
# ***iii. Plot Precision and Recall Curve***

# %%
display = PrecisionRecallDisplay.from_estimator(
    xgb_grid_model, X_test_final, y_test, name="xgb")

# %% [markdown]
# ***v. Apply Model Evaluation Checks***
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_model_evaluation.html

# %%
train_ds = Dataset(X_train_final.reset_index(drop=True), label=y_train_resampled.reset_index(drop=True), cat_features=[])
test_ds = Dataset(X_test_final.reset_index(drop=True), label=y_test.reset_index(drop=True), cat_features=[])

evaluation_suite = model_evaluation()
suite_result = evaluation_suite.run(train_ds, test_ds, xgb_grid_model)
suite_result.save_as_html(as_widget=False)
# Out:
#     <style>
#         progress {
#             -webkit-appearance: none;
#             border: none;
#             border-radius: 3px;
#             width: 300px;
#             height: 20px;
#             vertical-align: middle;
#             margin-right: 10px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-bar {
#             border-radius: 3px;
#             background-color: aliceblue;
#         }
#         progress::-webkit-progress-value {
#             background-color: #9d60fb;
#         }
#         progress::-moz-progress-bar {
#             background-color: #9d60fb;
#         }
#     </style>
# deepchecks - WARNING - Could not find built-in feature importance on the model, using permutation feature importance calculation instead
# deepchecks - INFO - Calculating permutation feature importance. Expected to finish in 10 seconds
# ...

# %%
X_test_final = rfa_xgb.transform(X_test)
y_pred = xgb_grid_model.predict(X_test_final)
y_pred_proba = xgb_grid_model.predict_proba(X_test_final)
xgb_pre_score = average_precision_score(y_test, y_pred_proba[:,1])
xgb_f1 = f1_score(y_test, y_pred)
xgb_recall = recall_score(y_test, y_pred)
print(xgb_pre_score, xgb_f1, xgb_recall)
# Out:
# 0.7612212244911197 0.7727272727272728 0.8380281690140845

# %% [markdown]
# ### Neural Network
#
# In the final step, you will make classification with Neural Network which is a Deep Learning algorithm.
#
# Neural networks are a series of algorithms that mimic the operations of a human brain to recognize relationships between vast amounts of data. They are used in a variety of applications in financial services, from forecasting and marketing research to fraud detection and risk assessment.
#
# A neural network contains layers of interconnected nodes. Each node is a perceptron and is similar to a multiple linear regression. The perceptron feeds the signal produced by a multiple linear regression into an activation function that may be nonlinear.
#
# In a multi-layered perceptron (MLP), perceptrons are arranged in interconnected layers. The input layer collects input patterns. The output layer has classifications or output signals to which input patterns may map.
#
# Hidden layers fine-tune the input weightings until the neural network’s margin of error is minimal. It is hypothesized that hidden layers extrapolate salient features in the input data that have predictive power regarding the outputs.
#
# You will discover **[how to create](https://towardsdatascience.com/building-our-first-neural-network-in-keras-bdc8abbc17f5)** your deep learning neural network model in Python using **[Keras](https://keras.io/about/)**. Keras is a powerful and easy-to-use free open source Python library for developing and evaluating deep learning models.
#
# - The steps you are going to cover for this algorithm are as follows:
#
#    *i. Import Libraries*
#
#    *ii. Define Model*
#
#    *iii. Compile Model*
#
#    *iv. Fit Model*
#
#    *v. Prediction and Model Evaluating*
#
#    *vi. Plot Precision and Recall Curve*

# %% [markdown]
# ***i. Import Libraries***

# %% [markdown]
# ***ii. Define Model***

# %% [markdown]
# ***iii. Compile Model***

# %%
y = df['Class']
X = df.drop(["Class"], axis=1).values

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    test_size=0.25,
                                                    random_state=44)
X_train, X_val, y_train, y_val = train_test_split(X_train,
                                                  y_train,
                                                  stratify=y_train,
                                                  test_size=0.25,
                                                  random_state=44)

# %%
scaler= RobustScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# %%
model = Sequential()
model.add(Dense(64, activation = 'relu', input_dim = X_train.shape[1]))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(32, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(16, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(8, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(4, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(2, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'sigmoid'))
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_43 (Dense)            (None, 64)                1984
#
#  batch_normalization_34 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_34 (Dropout)        (None, 64)                0
#
#  dense_44 (Dense)            (None, 32)                2080
#
#  batch_normalization_35 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_35 (Dropout)        (None, 32)                0
#
#  dense_45 (Dense)            (None, 16)                528
#
#  batch_normalization_36 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_36 (Dropout)        (None, 16)                0
#
#  dense_46 (Dense)            (None, 8)                 136
#
#  batch_normalization_37 (Bat  (None, 8)                32
#  chNormalization)
#
#  dropout_37 (Dropout)        (None, 8)                 0
#
# ...

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=10,
                           restore_best_weights = True)

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                  classes=np.unique(y_train),
                                                  y=y_train)
class_weights = {0: class_weights[0], 1: class_weights[1]}
class_weights
# Out:
# {0: 0.5008347507358987, 1: 299.9906015037594}

# %% [markdown]
# ***iv. Fit Model***

# %%
model.fit(x=X_train,
          y=y_train,
          validation_data=(X_val, y_val),
          batch_size=128,
          epochs=200,
          verbose=1,
          callbacks=[early_stop, PlotLossesKerasTF()],
          class_weight=class_weights)
# Out:
# Loss
# 	training         	 (min:    0.114, max:    0.612, cur:    0.141)
# 	validation       	 (min:    0.016, max:    0.424, cur:    0.020)
# recall
# 	training         	 (min:    0.808, max:    0.962, cur:    0.906)
# 	validation       	 (min:    0.809, max:    0.910, cur:    0.843)
# 1247/1247 [==============================] - 6s 5ms/step - loss: 0.1415 - recall: 0.9060 - val_loss: 0.0202 - val_recall: 0.8427
# Epoch 64: early stopping

# %% [markdown]
# ***v. Prediction and Model Evaluating***

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train) > 0.5
    y_pred = model.predict(X_test) > 0.5
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
eval_metric(model, X_train, y_train, X_test, y_test)
# Out:
# ...
# 2217/2217 [==============================] - 3s 1ms/step
# Test_Set
# [[70574   240]
#  [   15   103]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70814
#            1       0.30      0.87      0.45       118
#
#     accuracy                           1.00     70932
#    macro avg       0.65      0.93      0.72     70932
# weighted avg       1.00      1.00      1.00     70932
#
#
# Train_Set
# [[158840    489]
#  [    14    252]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    159329
#            1       0.34      0.95      0.50       266
#
#     accuracy                           1.00    159595
#    macro avg       0.67      0.97      0.75    159595
# weighted avg       1.00      1.00      1.00    159595

# %% [markdown]
# ***vi. Plot Precision and Recall Curve***

# %%
y_pred = model.predict(X_test) > 0.5
matrix_nn = confusion_matrix(y_test, y_pred)
cm_nn = pd.DataFrame(matrix_nn, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm_nn, annot=True, cbar=None, cmap="Blues", fmt = 'g')
plt.title("Confusion Matrix Neural Network"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()
# Out:
# 2217/2217 [==============================] - 3s 1ms/step

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 2217/2217 [==============================] - 3s 1ms/step

# %%
y_pred = model.predict(X_test) > 0.5
ANN_pre_score = average_precision_score(y_test, y_pred_proba)
ANN_f1 = f1_score(y_test, y_pred)
ANN_recall = recall_score(y_test, y_pred)
ANN_recall
# Out:
# 2217/2217 [==============================] - 3s 1ms/step
# 0.8728813559322034

# %% [markdown]
# ***v. Apply Model Evaluation Checks***
# * link : https://docs.deepchecks.com/stable/user-guide/tabular/auto_quickstarts/plot_quick_model_evaluation.html

# %%
#train_ds = Dataset(X_train.reset_index(drop=True), label=y_train.reset_index(drop=True), cat_features=[])
#test_ds = Dataset(X_test.reset_index(drop=True), label=y_test.reset_index(drop=True), cat_features=[])

#evaluation_suite = model_evaluation()
#suite_result = evaluation_suite.run(train_ds, test_ds, model)
#suite_result.show()

# %% [markdown]
# ### SMOT UNDER SAMPLING

# %%
y = df['Class']
X = df.drop(["Class"], axis=1).values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                  test_size=0.25, random_state=44)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                  test_size= 0.25, random_state=44)

# %%
scaler= RobustScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# %%
undersample = RandomUnderSampler(sampling_strategy=1)

# %%
X_train_under, y_train_under = undersample.fit_resample(X_train, y_train)
test = pd.DataFrame(y_train_under, columns = ['Class'])

# %%
fig, axs = plt.subplots(ncols=2, figsize=(13,4.5))
sns.countplot(x="Class", data=df, ax=axs[0])
sns.countplot(x="Class", data=test, ax=axs[1])

fig.suptitle("Class repartition before and after undersampling")
a1=fig.axes[0]
a1.set_title("Before")
a2=fig.axes[1]
a2.set_title("After")
# Out:
# Text(0.5, 1.0, 'After')

# %%
model = Sequential()
model.add(Dense(64, activation = 'relu', input_dim = X_train.shape[1]))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(32, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(16, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(8, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(4, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(2, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(1, activation = 'sigmoid'))
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=['Recall'])
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_50 (Dense)            (None, 64)                1984
#
#  batch_normalization_40 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_40 (Dropout)        (None, 64)                0
#
#  dense_51 (Dense)            (None, 32)                2080
#
#  batch_normalization_41 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_41 (Dropout)        (None, 32)                0
#
#  dense_52 (Dense)            (None, 16)                528
#
#  batch_normalization_42 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_42 (Dropout)        (None, 16)                0
#
#  dense_53 (Dense)            (None, 8)                 136
#
#  batch_normalization_43 (Bat  (None, 8)                32
#  chNormalization)
#
#  dropout_43 (Dropout)        (None, 8)                 0
#
# ...

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=10,
                           restore_best_weights = True)

# %%
model.fit(x=X_train_under,
          y=y_train_under,
          validation_data=(X_val, y_val),
          batch_size=128,
          epochs=50,
          verbose=1,
          callbacks=[early_stop, PlotLossesKerasTF()])
# Out:
# Loss
# 	training         	 (min:    0.522, max:    0.839, cur:    0.522)
# 	validation       	 (min:    0.631, max:    0.703, cur:    0.652)
# recall
# 	training         	 (min:    0.746, max:    0.891, cur:    0.891)
# 	validation       	 (min:    0.022, max:    0.867, cur:    0.867)
# 4/4 [==============================] - 1s 287ms/step - loss: 0.5221 - recall: 0.8906 - val_loss: 0.6523 - val_recall: 0.8667
# Epoch 11: early stopping

# %%
eval_metric(model, X_train_under, y_train_under, X_test, y_test)
# Out:
# ...
# 2217/2217 [==============================] - 3s 1ms/step
# Test_Set
# [[57286 13519]
#  [  126     1]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     70805
#            1       0.00      0.01      0.00       127
#
#     accuracy                           0.81     70932
#    macro avg       0.50      0.41      0.45     70932
# weighted avg       1.00      0.81      0.89     70932
#
#
# Train_Set
# [[213  43]
#  [253   3]]
#               precision    recall  f1-score   support
#
#            0       0.46      0.83      0.59       256
#            1       0.07      0.01      0.02       256
#
#     accuracy                           0.42       512
#    macro avg       0.26      0.42      0.30       512
# weighted avg       0.26      0.42      0.30       512

# %%
y_pred = model.predict(X_test) > 0.5
matrix_nn = confusion_matrix(y_test, y_pred)
cm_nn = pd.DataFrame(matrix_nn, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm_nn, annot=True, cbar=None, cmap="Blues", fmt = 'g')
plt.title("Confusion Matrix Neural Network"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()
# Out:
# 2217/2217 [==============================] - 3s 1ms/step

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 2217/2217 [==============================] - 3s 1ms/step

# %%
y_pred = model.predict(X_test) > 0.5
ANN_smot_under_pre_score = average_precision_score(y_test, y_pred_proba)
ANN_smot_under_f1 = f1_score(y_test, y_pred)
ANN_smot_under_recall = recall_score(y_test, y_pred)
ANN_smot_under_recall
# Out:
# 2217/2217 [==============================] - 3s 1ms/step
# 0.007874015748031496

# %% [markdown]
# ### SMOT OVER SAMPLING

# %%
y = df['Class']
X = df.drop(["Class"], axis=1).values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                  test_size=0.25, random_state=44)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                  test_size= 0.25, random_state=44)

# %%
scaler= RobustScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# %%
oversample = RandomOverSampler(sampling_strategy=0.1, random_state=1)

# %%
X_train_over, y_train_over = oversample.fit_resample(X_train, y_train)
test = pd.DataFrame(y_train_over, columns = ['Class'])

# %%
fig, axs = plt.subplots(ncols=2, figsize=(13,4.5))
sns.countplot(x="Class", data=df, ax=axs[0])
sns.countplot(x="Class", data=test, ax=axs[1])

fig.suptitle("Class repartition before and after undersampling")
a1=fig.axes[0]
a1.set_title("Before")
a2=fig.axes[1]
a2.set_title("After")
# Out:
# Text(0.5, 1.0, 'After')

# %%
model = Sequential()
model.add(Dense(64, activation = 'relu', input_dim = X_train.shape[1]))
model.add(BatchNormalization())
model.add(Dropout(0.7))
model.add(Dense(32, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(16, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(8, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation = 'sigmoid'))
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_57 (Dense)            (None, 64)                1984
#
#  batch_normalization_46 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_46 (Dropout)        (None, 64)                0
#
#  dense_58 (Dense)            (None, 32)                2080
#
#  batch_normalization_47 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_47 (Dropout)        (None, 32)                0
#
#  dense_59 (Dense)            (None, 16)                528
#
#  batch_normalization_48 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_48 (Dropout)        (None, 16)                0
#
#  dense_60 (Dense)            (None, 8)                 136
#
#  batch_normalization_49 (Bat  (None, 8)                32
#  chNormalization)
#
#  dropout_49 (Dropout)        (None, 8)                 0
#
# ...

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=5,
                           restore_best_weights = True)

# %%
model.fit(x=X_train_over,
          y=y_train_over,
          validation_data=(X_val, y_val),
          batch_size= 1024,
          epochs=20,
          verbose=1,
          callbacks=[early_stop, PlotLossesKerasTF()])
# Out:
# Loss
# 	training         	 (min:    0.057, max:    0.486, cur:    0.057)
# 	validation       	 (min:    0.007, max:    0.223, cur:    0.007)
# recall
# 	training         	 (min:    0.607, max:    0.868, cur:    0.868)
# 	validation       	 (min:    0.756, max:    0.789, cur:    0.789)
# 172/172 [==============================] - 2s 10ms/step - loss: 0.0572 - recall: 0.8678 - val_loss: 0.0071 - val_recall: 0.7889

# %%
eval_metric(model, X_train_over, y_train_over, X_test, y_test)
# Out:
# ...
# 2217/2217 [==============================] - 2s 979us/step
# Test_Set
# [[70741    64]
#  [   21   106]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70805
#            1       0.62      0.83      0.71       127
#
#     accuracy                           1.00     70932
#    macro avg       0.81      0.92      0.86     70932
# weighted avg       1.00      1.00      1.00     70932
#
#
# Train_Set
# [[159203    136]
#  [  1928  14005]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    159339
#            1       0.99      0.88      0.93     15933
#
#     accuracy                           0.99    175272
#    macro avg       0.99      0.94      0.96    175272
# weighted avg       0.99      0.99      0.99    175272

# %%
y_pred = model.predict(X_test) > 0.5
matrix_nn = confusion_matrix(y_test, y_pred)
cm_nn = pd.DataFrame(matrix_nn, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm_nn, annot=True, cbar=None, cmap="Blues", fmt = 'g')
plt.title("Confusion Matrix Neural Network"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()
# Out:
# 2217/2217 [==============================] - 2s 1ms/step

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 2217/2217 [==============================] - 2s 1ms/step

# %%
y_pred = model.predict(X_test) > 0.5
ANN_smot_over_pre_score = average_precision_score(y_test, y_pred_proba)
ANN_smot_over_f1 = f1_score(y_test, y_pred)
ANN_smot_over_recall = recall_score(y_test, y_pred)
ANN_smot_over_recall
# Out:
# 2217/2217 [==============================] - 2s 999us/step
# 0.8346456692913385

# %% [markdown]
# ### Optuna

# %%
trial_metric = "Recall"
batch_size = 512
def create_model(trial):
    # Some hyperparameters we want to optimize
    n_units1 = trial.suggest_int('n_units1', 8, 128)
    n_units2 = trial.suggest_int('n_units2', 8, 128)
    n_units3 = trial.suggest_int('n_units3', 8, 128)
    optimizer = trial.suggest_categorical("optimizer",
                                          [Adam, Adadelta, RMSprop, Nadam])
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-8, 1.3e-1)

    tf.random.set_seed(42)
    model = Sequential()
    model.add(Dense(n_units1, input_dim=X_train_over.shape[1], activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.7))
    model.add(Dense(n_units2, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_units3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizer(learning_rate=learning_rate),
                  metrics=[trial_metric])
    return model

def objective(trial):
    model = create_model(trial)
    model.fit(X_train_over,
              y_train_over,
              validation_data=(X_val, y_val),
              batch_size=batch_size,
              epochs=50,
              callbacks=[early_stop],
              verbose=0)
    score = model.evaluate(X_test, y_test, verbose=0)[1]
    return score

# %%
import optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=5)
study.best_params
# Out:
# [I 2023-03-05 17:19:43,627] A new study created in memory with name: no-name-3f3d7170-6a2a-4cbf-870b-95d88578514b
# [I 2023-03-05 17:20:53,938] Trial 0 finished with value: 0.8503937125205994 and parameters: {'n_units1': 78, 'n_units2': 64, 'n_units3': 70, 'optimizer': <class 'keras.optimizers.optimizer_v2.rmsprop.RMSprop'>, 'learning_rate': 0.00021445680883387422}. Best is trial 0 with value: 0.8503937125205994.
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# [I 2023-03-05 17:21:12,091] Trial 1 finished with value: 0.7952755689620972 and parameters: {'n_units1': 105, 'n_units2': 85, 'n_units3': 92, 'optimizer': <class 'keras.optimizers.optimizer_v2.adam.Adam'>, 'learning_rate': 0.06604040295315859}. Best is trial 0 with value: 0.8503937125205994.
# Restoring model weights from the end of the best epoch: 15.
# Epoch 20: early stopping
# ...

# %%
unit1, unit2, unit3, optimizer, lr = (study.best_params['n_units1'],
                               study.best_params['n_units2'],
                               study.best_params['n_units3'],
                               study.best_params['optimizer'],
                               study.best_params['learning_rate'])
tf.random.set_seed(42)
model = Sequential()
model.add(Dense(unit1, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.7))
model.add(Dense(unit2, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(unit3, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation="sigmoid"))
opt = optimizer(learning_rate=lr)
model.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Recall"])
model.fit(X_train_over,
          y_train_over,
          validation_data=(X_val, y_val),
          batch_size=512,
          epochs=50,
          callbacks=[early_stop, PlotLossesKerasTF()],
          verbose=1)
# Out:
# Loss
# 	training         	 (min:    0.028, max:    0.460, cur:    0.028)
# 	validation       	 (min:    0.006, max:    0.108, cur:    0.006)
# recall
# 	training         	 (min:    0.798, max:    0.940, cur:    0.940)
# 	validation       	 (min:    0.778, max:    0.833, cur:    0.811)
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0277 - recall: 0.9398 - val_loss: 0.0060 - val_recall: 0.8111

# %%
eval_metric(model, X_train_over, y_train_over, X_test, y_test)
# Out:
# ...
# 2217/2217 [==============================] - 2s 997us/step
# Test_Set
# [[70719    86]
#  [   19   108]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70805
#            1       0.56      0.85      0.67       127
#
#     accuracy                           1.00     70932
#    macro avg       0.78      0.92      0.84     70932
# weighted avg       1.00      1.00      1.00     70932
#
#
# Train_Set
# [[159145    194]
#  [   604  15329]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    159339
#            1       0.99      0.96      0.97     15933
#
#     accuracy                           1.00    175272
#    macro avg       0.99      0.98      0.99    175272
# weighted avg       1.00      1.00      1.00    175272

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 2217/2217 [==============================] - 2s 984us/step

# %%
y_pred_proba = model.predict(X_test)
matrix_nn = confusion_matrix(y_test, y_pred)
cm_nn = pd.DataFrame(matrix_nn, index=['not_fraud', 'fraud'], columns=['not_fraud', 'fraud'])

sns.heatmap(cm_nn, annot=True, cbar=None, cmap="Blues", fmt = 'g')
plt.title("Confusion Matrix Neural Network"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()
# Out:
# 2217/2217 [==============================] - 2s 986us/step

# %%
y_pred = model.predict(X_test) > 0.5
optuna_smot_pre_score = average_precision_score(y_test, y_pred_proba)
optuna_smot_f1 = f1_score(y_test, y_pred)
optuna_smot_recall = recall_score(y_test, y_pred)
print(optuna_smot_pre_score, optuna_smot_f1, optuna_smot_recall)
# Out:
# 2217/2217 [==============================] - 2s 998us/step
# 0.7215431555130533 0.6728971962616823 0.8503937007874016

# %% [markdown]
# ## Model Comparison

# %%
compare = pd.DataFrame({
    "Model": ["ANN","ANN_Smot_Under","ANN_Smot_Over","ANN_Optuna_Smot", "Log_Smot_Over", "RF_Smot_Over", "XGB_Smot_Over"],
    "F1": [ANN_f1, ANN_smot_under_f1, ANN_smot_over_f1, optuna_smot_f1, log_f1, rf_f1, xgb_f1],
    "Recall": [ANN_recall ,ANN_smot_under_recall,ANN_smot_over_recall, optuna_smot_recall, log_recall, rf_recall, xgb_recall],
    "AP": [ANN_pre_score,ANN_smot_under_pre_score, ANN_smot_over_pre_score, optuna_smot_pre_score, log_pre_score, rf_pre_score, xgb_pre_score]
})




def labels(ax):
    for p in ax.patches:
        width = p.get_width()  # get bar length
        ax.text(
            width,  # set the text at 1 unit right of the bar
            p.get_y() +
            p.get_height() / 2,  # get Y coordinate + X coordinate / 2
            '{:1.3f}'.format(width),  # set variable to display, 2 decimals
            ha='left',  # horizontal alignment
            va='center')  # vertical alignment


plt.figure(figsize=(14, 10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax = sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax = sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="AP", ascending=False)
ax = sns.barplot(x="AP", y="Model", data=compare, palette="Blues_d")
labels(ax)
plt.show()

# %% [markdown]
# ## 4. Model Deployement
# You cooked the food in the kitchen and moved on to the serving stage. The question is how do you showcase your work to others? Model Deployement helps you showcase your work to the world and make better decisions with it. But, deploying a model can get a little tricky at times. Before deploying the model, many things such as data storage, preprocessing, model building and monitoring need to be studied.
#
# Deployment of machine learning models, means making your models available to your other business systems. By deploying models, other systems can send data to them and get their predictions, which are in turn populated back into the company systems. Through machine learning model deployment, can begin to take full advantage of the model you built.
#
# Data science is concerned with how to build machine learning models, which algorithm is more predictive, how to design features, and what variables to use to make the models more accurate. However, how these models are actually used is often neglected. And yet this is the most important step in the machine learning pipline. Only when a model is fully integrated with the business systems, real values ​​can be extract from its predictions.
#
# After doing the following operations in this notebook, jump to a proper IDE and create your web app with Streamlit API.

# %% [markdown]
# ### Save and Export the Best Model

# %%
df = pd.read_csv("creditcard.csv")
df.drop_duplicates(inplace=True)


X = df.drop(labels=['Class'], axis = 1)
y = df['Class']
            
scaler = RobustScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
pickle.dump(scaler, open('RobustScaler', 'wb'))

oversample = RandomOverSampler(sampling_strategy=0.1, random_state=1)
X_over, y_over = oversample.fit_resample(X, y)
X_over = pd.DataFrame(X_over, columns=X.columns)
pickle.dump(oversample, open('RandomOverSampler', 'wb'))

model = XGBClassifier(n_jobs = -1, random_state=101)
rfa_xgb = RecursiveFeatureAddition(
    variables=None,  # automatically evaluate all numerical variables
    estimator=model,  # the ML model
    scoring=make_scorer(f1_score, average=None, labels=[1]),  # the metric we want to evalute
    threshold=0.0001,  # the minimum performance increase needed to select a feature
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=1)  # cross-validation
)

rfa_xgb.fit(X_over, y_over)
X_final = rfa_xgb.transform(X_over)
pickle.dump(rfa_xgb, open('RecursiveFeatureAddition', 'wb'))

scoring=make_scorer(f1_score, average=None, labels=[1])
model_final = XGBClassifier(n_estimators = 50, max_depth = 3, learning_rate = 0.1, 
                            subsample = 0.2, colsample_bytree = 0.2, colsample_bylevel = 1, 
                            n_jobs = -1, random_state=101, metric = 'logloss')

model_final.fit(X_final, y_over)
pickle.dump(model_final, open('XGB', 'wb'))
y_pred = model_final.predict(X_final)
print(classification_report(y_over, y_pred))
# Out:
# [17:51:13] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:51:25] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:51:36] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %% [markdown]
# ### Final Model without Outlier Correction

# %%
rfa_xgb.get_feature_names_out()
# Out:
# ['V4', 'V10', 'V13', 'V14', 'V17', 'Amount']

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(labels=['Class'], axis=1), 
                                                    df['Class'], stratify = df['Class'], test_size=0.3, random_state=0)

scaler = RobustScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

oversample = RandomOverSampler(sampling_strategy=0.1, random_state=1)
X_train_over, y_train_over = oversample.fit_resample(X_train, y_train)
X_train_over = pd.DataFrame(X_train_over, columns=X_train.columns)

model_final = XGBClassifier(n_estimators = 50, max_depth = 3, learning_rate = 0.1, 
                            subsample = 0.2, colsample_bytree = 0.2, colsample_bylevel = 1, 
                            n_jobs = -1, random_state=101, metric = 'logloss')
X_train_over = X_train_over[rfa_xgb.get_feature_names_out()]
X_test = X_test[rfa_xgb.get_feature_names_out()]

model_final.fit(X_train_over, y_train_over)
eval_metric(model_final, X_train_over, y_train_over, X_test, y_test)
# Out:
# [18:27:21] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:27:21] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Test_Set
# [[84919    57]
#  [   23   119]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84976
#            1       0.68      0.84      0.75       142
#
# ...

# %% [markdown]
# ### Final Model with Outlier Correction

# %%
X_train, X_test, y_train, y_test = train_test_split(df_out.drop(labels=['Class'], axis=1), 
                                                    df_out['Class'], stratify = df_out['Class'], test_size=0.3, random_state=0)

scaler = RobustScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

oversample = RandomOverSampler(sampling_strategy=0.1, random_state=1)
X_train_over, y_train_over = oversample.fit_resample(X_train, y_train)
X_train_over = pd.DataFrame(X_train_over, columns=X_train.columns)

model_final = XGBClassifier(n_estimators = 50, max_depth = 3, learning_rate = 0.1, 
                            subsample = 0.2, colsample_bytree = 0.2, colsample_bylevel = 1, 
                            n_jobs = -1, random_state=101, metric = 'logloss')
X_train_over = X_train_over[rfa_xgb.get_feature_names_out()]
X_test = X_test[rfa_xgb.get_feature_names_out()]

model_final.fit(X_train_over, y_train_over)
eval_metric(model_final, X_train_over, y_train_over, X_test, y_test)
# Out:
# [18:32:50] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:32:50] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Test_Set
# [[79051    70]
#  [   12     1]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     79121
#            1       0.01      0.08      0.02        13
#
# ...

# %% [markdown]
# ### Save and Export Variables

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
